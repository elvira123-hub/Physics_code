# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# Graphs for exercise 1


#Case1: Step function


epsilon=0.01

# Set function
def Stepfunct(x):
    return np.where(abs(x)<=(epsilon/2),(1/epsilon),0)

# Exact Solution
x=0.45
def Exact(x):
    return cos(x)
# print(Exact(x))

# approximation 𝐼(𝑥)
a=-1
b=1
# =N=np.array([16, 32, 64, 128, 256, 512, 1024])
def f(phi):
    return Exact(phi)*Stepfunct(phi-x)

# Trapezoidale rule
def Trap(f,a,b,Nvec):
    h=(b-a)/Nvec
    T=0
    for i in range(Nvec):
        T+=h/2*(f(phi[i]) + f(phi[i+1]))
    return T
# Trap(f,-epsilon/2,epsilon/2,N)

# trapezoidal rule approximation
Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
for i in range(len(Nvec)):
#     x=linspace(-1,1,Nvec[i]+1)
    phi=linspace(a,b,Nvec[i]+1)
    Fx = Trap(f,-epsilon/2,epsilon/2,Nvec[i])
#     print(Fx)
    print("{:8d} {:24.16f} {:12.4e}".format(Nvec[i],Fx,abs(Fx-cos(0.45))))
# Out:
#       16       0.0000000000000000   9.0045e-01
#       32       0.0000000000000000   9.0045e-01
#       64       0.0000000000000000   9.0045e-01
#      128       0.0070240893793761   8.9342e-01
#      256       0.0070373419679613   8.9341e-01
#      512       0.0052780198987209   8.9517e-01
#     1024       0.0043983555084100   8.9605e-01

# %%
# XX=f(phi)
# plt.plot(phi,XX)
# plt.plot()

# %%
# Graphs for exercise 1


#Case2: Hat function


epsilon=0.01

# Set function
def Hatfunct(x):
    return where(abs(x)<=(epsilon/2),(2/epsilon)*(1-(abs(2*(x))/epsilon)),0)

# Exact Solution
x=0.45
def Exact(x):
    return cos(x)
# print(Exact(x))

# approximation 𝐼(𝑥)
a=-1
b=1
# Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
def g(phi):
    return Exact(phi)*Hatfunct(phi-x)

# Trapezoidale rule
def Trap(g,a,b,N):
    h=(b-a)/N
    T=0
    for i in range(N):
        T+=h/2*(g(phi[i]) + g(phi[i+1]))
    return T

# trapezoidal rule approximation
Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
for i in range(len(Nvec)):
#     x=linspace(-1,1,Nvec[i]+1)
    phi=linspace(a,b,Nvec[i]+1)
    Fx = Trap(g,-epsilon/2,epsilon/2,Nvec[i])
#     print(Fx)
    print("{:8d} {:24.16f} {:12.4e}".format(Nvec[i],Fx,abs(Fx-cos(0.45))))
# Out:
#       16       0.0000000000000000   9.0045e-01
#       32       0.0000000000000000   9.0045e-01
#       64       0.0000000000000000   9.0045e-01
#      128       0.0052680670345321   8.9518e-01
#      256       0.0030746956770502   8.9737e-01
#      512       0.0045062491321492   8.9594e-01
#     1024       0.0043968092859373   8.9605e-01

# %%
# XX=g(phi)
# plt.plot(phi,XX)
# plt.plot()

# %%
# Graphs for exercise 1


#Case3: Heat Kernel


epsilon=10e-05

# Set function
def Heatkernel(x):
    return (1/sqrt(4*np.pi*epsilon)*exp(-x**2/(4*epsilon)))

# Exact Solution
x=0.45
def Exact(x):
    return cos(x)
# print(Exact(x))

# approximation 𝐼(𝑥)
a=-1
b=1
# Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
def H(phi):
    return Exact(phi)*Heatkernel(phi-x)

# Trapezoidale rule
def Trap(f,a,b,N):
    h=(b-a)/N
    T=0
    for i in range(N):
        T+=h/2*(H(phi[i]) + H(phi[i+1]))
    return T

# trapezoidal rule approximation
Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
for i in range(len(Nvec)):
#     x=linspace(-1,1,Nvec[i]+1)
    phi=linspace(a,b,Nvec[i]+1)
    Fx = Trap(H,-epsilon/2,epsilon/2,Nvec[i])
#     print(Fx)
    print("{:8d} {:24.16f} {:12.4e}".format(Nvec[i],Fx,abs(Fx-cos(0.45))))
# Out:
#       16       0.0000002988194429   9.0045e-01
#       32       0.0000541797477513   9.0039e-01
#       64       0.0000437563780768   9.0040e-01
#      128       0.0000450178554403   9.0040e-01
#      256       0.0000450178531072   9.0040e-01
#      512       0.0000450178531072   9.0040e-01
#     1024       0.0000450178531072   9.0040e-01

# %%
# XX=H(phi)
# plt.plot(phi,XX)
# plt.plot()

# %% [markdown]
# # Hat function

# %% [markdown]
# Hat function : Your results are right.  And no, you can’t really combine them - this is a piecewise defined function.   If you can plot it, that would be great.   Might take more than one where call.   The piece in $0 < x < \varepsilon/2$ can also be written $1-2(1-\eta)^2$.
# Heat kernel :  There are different ways to express the resulting function, but your answer should involve $\varepsilon$.    For this one, you don’t need to make the substitution $x = -\varepsilon/2 + \eta \varepsilon$, but can use the fact that
# \begin{equation}
# \lim_{x \to \infty} \mbox{erf}(x) = 1
# \end{equation}
# and
# \begin{equation}
# \lim_{x \to -\infty} \mbox{erf}(x) = -1
# \end{equation}
# Also, $\mbox{erf}(x) + \mbox{erfc}(x) = 1$ might be useful.  You can plot your solution to see that you have a formulation that works.  But as I said, there could be more than one formulation, depending on whether you use erf or erfc. (edited)

# %%
figure(6)
clf()

# Sample Heaviside function for the Step function

def heaviside_step(x,a):
    return where(abs(x) <= a/2, x/a + 1/2, heaviside(x,1))

# Exact heavside function
xf = linspace(-1,1,513)
plot(xf,heaviside(xf,1),'r',label='heaviside (H(x))')
plot(xf,heaviside_step(xf,0.5), 'g',label=' $\epsilon =0.5$ Heaviside (Step)')
plot(xf,heaviside_step(xf,0.25), 'y',label=' $\epsilon =0.25$ Heaviside (Step)')
    
# Heaviside function (Step function)
x = linspace(-1,1,101)
H = heaviside_step(x,0.1)
plot(x,heaviside_step(x,0.1), 'b',label=' $\epsilon =0.1$ Heaviside (Step)')
# plot(x,heaviside_hat(x,0.05), 'b',label=' $\epsilon =0.05$ Heaviside (Hat)')
xlabel('$x$')
ylabel('$H_{\epsilon}(x)$')


    
legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
figure(7)
clf()

def heaviside_hat(x,epsilon):
    condition1 = x <-epsilon/2
    condition2 = np.logical_and(-epsilon/2 <= x, x < 0)
    condition3 = np.logical_and(0 <= x, x < epsilon/2 )
    condition4 = x > epsilon/2

    h = where(condition1, 0.0, 0.0)
    h = where(condition2, 1/2 + ((2/epsilon)*(x+(((x)**2)/(epsilon)))), h)
    h = where(condition3, 1/2 + ((2/(epsilon))*(x-(((x)**2)/(epsilon)))), h)
    h = where(condition4, 1.0, h)
    return h    

# Exact heavside function
xf = linspace(-1,1,101)
plot(xf,heaviside(xf,1),'r',label=' Heaviside (H(x))')
plot(xf,heaviside_hat(xf,0.5),'g',label= ' $\epsilon =0.5$  Heaviside (Hat)')
plot(xf,heaviside_hat(xf,0.25),'y', label= '$\epsilon =0.25$  Heaviside (Hat)')
# plot(xf,heaviside_hat(xf,10e-5),'k',linewidth=1.5)


# Heaviside function (Hat function)
x = linspace(-1,1,101)
# h = heaviside_hat(x,0.1)
plot(x,heaviside_hat(x,0.1), 'b', label= ' $\epsilon =0.1$  Heaviside (Hat)')
# plot(x,heaviside_hat(x,0.05), 'b',label=' $\epsilon =0.05$ Heaviside (Hat)')
# plot(x,heaviside_hat(x,10e-5), 'b',label='Heaviside (Hat)')
# plot(x,heaviside_hat(x,10e-1), 'b',label='Heaviside (Hat)')
xlabel('$x$')
ylabel('$H_{\epsilon}(x)$')

legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# When you integrate
# \begin{equation}
# H_\varepsilon(x) = \frac{1}{\sqrt{4\pi\varepsilon}}\int_{-\infty}^x  e^{\frac{-\xi^2}{4\varepsilon}} \; d\xi
# \end{equation}
# you make a substitution $\eta = \xi/\sqrt{4\varepsilon}$ and the upper limit of integration becomes $x/\sqrt{4\varepsilon}$.   This is how $\varepsilon$ is involved in the final answer.
# For this delta function, you may want to take $\varepsilon=10^{-5}$ to get a sharper Heaviside approximation. (edited)

# %%
figure(8)
clf()
from scipy.special import erf
def heaviside_heat(x,epsilon):
      return 1/2 + 1/2*erf((x)/((4*epsilon)*(0.5)))

# Exact heavside function
xf = linspace(-1,1,513)
plot(xf,heaviside(xf,1),'r',label='Heaviside (H(x))')
# plot(xf,heaviside_heat(xf,10e-5),'b',linewidth=0.5)



# Heaviside function (Hat function)
x = linspace(-1,1,101)
# h = heaviside_heat(x,10e-5)
plot(x, heaviside_heat(x,10e-5), 'b', label= ' $\epsilon = 10e-5 $ Heavisid(Hat)')
plot(x, heaviside_heat(x,0.05), 'g',label= ' $\epsilon = 0.05 $  Heaviside (Hat)')
plot(x, heaviside_heat(x,0.1), 'y',label= ' $\epsilon = 0.1 $  Heaviside (Hat)')
    
    
    
    
    
    
xlabel('$x$')
ylabel('$H_{\epsilon}(x)$')

legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# You can evaluate $\delta(t-\tau)$ in exactly the same way you evaluate $\delta(x-\xi)$.  It is just a change in the name of the variable.
# (Your Green’s function is correct, but the last equality is not correct, since
# \begin{equation}
# \delta(x - \xi - c(t-\tau))H(t-\tau) \ne \delta(x-\xi)\delta(t-\tau)H(t-\tau)
# \end{equation} (edited)

# %% [markdown]
# When you integrate
# \begin{equation}
# H_\varepsilon(x) = \frac{1}{\sqrt{4\pi\varepsilon}}\int_{-\infty}^x  e^{\frac{-\xi^2}{4\varepsilon}} \; d\xi
# \end{equation}
# you make a substitution $\eta = \xi/\sqrt{4\varepsilon}$ and the upper limit of integration:$x/\sqrt{4\varepsilon}$.   This is how $\varepsilon$ is involved in the final answer.
# For this delta function, you may want to take $\varepsilon=10^{-5}$ to get a sharper Heaviside approximation. (edited)

# %% [markdown]
# Hello @donnacalhoun
# I used this substitution: $\eta = \xi/\sqrt{4\varepsilon}$ and the upper limit of integration $x/\sqrt{4\varepsilon}$ and I found $\int_{ - \infty }^x {{{\hat \delta }_\varepsilon }} (\xi ){\mkern 1mu} d\xi  = \frac{1}{2} + \frac{1}{2}\mbox{erf}\left( \frac{x}{\sqrt{4\varepsilon}} \right)$ Or according to the graph I got:$\lim_{x \to -\infty} \mbox{erf}(x)$ is "0" not "-1"  which is not verified.
#
# For the <font color=red>Hat function<\font> at the left, I used  $\varepsilon=10^{-5}$ But the shape of the Heaviside approximation should be fit the Heaviside function? How to make the gap so that we can see clearly.

# %% [markdown]
# I just noticed that the scale on the y-axis is very small.    This should be about $1/\varepsilon$, depending on which delta function you choose.

# %% [markdown]
# It looks like the solution isn’t moving.   But the general shape is correct.   Basically, for $t > t_m$, the solution is is just a delta function that translates to the right with speed 1.

# %% [markdown]
# Using $\lim_{x \to -\infty} \mbox{erfc}(x) = -1$, the limiting value for your expression for the Heaviside function $\frac{1}{2} + \frac{1}{2} \mbox{erf}(x/\sqrt{4\varepsilon}) = 0$.  So what you have done is correct!
