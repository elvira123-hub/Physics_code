# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\MAXTRONIQUE\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# # Hat function

# %% [markdown]
# Hat function : Your results are right.  And no, you can’t really combine them - this is a piecewise defined function.   If you can plot it, that would be great.   Might take more than one where call.   The piece in $0 < x < \varepsilon/2$ can also be written $1-2(1-\eta)^2$.
# Heat kernel :  There are different ways to express the resulting function, but your answer should involve $\varepsilon$.    For this one, you don’t need to make the substitution $x = -\varepsilon/2 + \eta \varepsilon$, but can use the fact that
# \begin{equation}
# \lim_{x \to \infty} \mbox{erf}(x) = 1
# \end{equation}
# and
# \begin{equation}
# \lim_{x \to -\infty} \mbox{erf}(x) = -1
# \end{equation}
# Also, $\mbox{erf}(x) + \mbox{erfc}(x) = 1$ might be useful.  You can plot your solution to see that you have a formulation that works.  But as I said, there could be more than one formulation, depending on whether you use erf or erfc. (edited)

# %%
# figure(6)
# clf()

# Sample Heaviside function for the Step function
e= 10e-5
def heaviside_hat(x):
    return where(abs(x) <= e/2, 1/2 + ((2/e)*(x+(((x)**2)/e))), heaviside(x,1))

# Exact heavside function
xf = linspace(-3,3,101)
plot(xf,heaviside(xf,1),'r',label='H(x)')
# plot(xf,heaviside_hat(xf,0.1), 'k',linewidth=0.9)
    
# Heaviside function (Step function)
x = linspace(-1,1,101)
# H = heaviside_hat(x,0.1)
plot(x,heaviside_hat(x), 'b.',label='Heaviside (hat)')


    
legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# epsilon=0.1
def heaviside_hat(x):
    condition1 = x < -10e-5/2
    condition2 = np.logical_and(-10e-5/2 <= x, x < 0)
    condition3 = np.logical_and(0 <= x, x < 10e-5/2 )
    condition3 = x > 10e-5/2

    h = where(condition1, 0.0, 0.0)
    h = where(condition2, 1/2 + ((2/10e-5)*(x+(((x)**2)/10e-5))), h)
    h = where(condition3, 1/2 + ((2/10e-5)*(x-(((x)**2)/10e-5))), h)
    h = where(condition4, 1.0, h)
    return h    

# Exact heavside function
xf = linspace(-1,1,101)
plot(xf,heaviside(xf,1),'r',label='H(x)')
# plot(xf,heaviside_hat(xf),'g',linewidth=0.5)

# Heaviside function (Hat function)
x = linspace(-1,1,101)
h = heaviside_hat(x)
plot(x,h, 'b*',label='Heaviside (Hat)')


legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-638802d3a90c> in <module>
#      19 # Heaviside function (Hat function)
#      20 x = linspace(-1,1,101)
# ---> 21 h = heaviside_hat(x)
#      22 plot(x,h, 'b*',label='Heaviside (Hat)')
#      23
#
# <ipython-input-41-638802d3a90c> in heaviside_hat(x)
#       9     h = where(condition2, 1/2 + ((2/10e-5)*(x+(((x)**2)/10e-5))), h)
#      10     h = where(condition3, 1/2 + ((2/10e-5)*(x-(((x)**2)/10e-5))), h)
# ---> 11     h = where(condition4, 1.0, h)
#      12     return h
#      13
#
# NameError: name 'condition4' is not defined
