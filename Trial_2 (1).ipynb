# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
L = 1
T_final = L**2/4

def f_conv(y):
    return np.exp(-100*(y-0.5)**2)

def f(x1):
    # Variable of integration is x1;  x2 defined externally
    # return (1/np.sqrt(4*np.pi*T))*np.exp(-(x2-x1)**2/(4*T) - 100*x1**2)
    return (1/np.sqrt(4*np.pi*T_final))*np.exp(-(x2-x1)**2/(4*T_final))*f_conv(x1)

# a=-4
# b=4


# also use  scipy.integrate.quad
def Trap(f,a,b,N):
    y = np.linspace(a,b,N+1)
    h = (b-a)/N
    T = 0
    for i in range(N):
        T += h/2*(f(y[i]) + f(y[i+1]))
    return T


# Take interval of integration [0,L]
ax = 0
bx = L

N = 64
# h = (bx-ax)/N

# dx=0.05

C_0 =1
# b1= -1
# x2=np.arange(b1,L+dx,dx) 
x2vec = np.linspace(ax,bx,N+1)
# x1 = np.linspace(a,b,100)
# h = x1[1]-x1[0]
theta = np.zeros(x2vec.shape)
for j in range(N+1):
    x2 = x2vec[j]
    theta[j] = Trap(f,ax,bx,N)
#     for i in range(1,len(x1)):
#         A1[j,i-1] = (h/2)*(f(x2[j],x1[i-1])+ f(x2[j],x1[i]))
# A1[-1]
# 
b = 4*np.pi*L**2*C_0*theta

# %%
# b_1 = np.pi*L**2*C_0*A1[-1,:]
b_1 = b
plt.plot(x2vec,b_1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
