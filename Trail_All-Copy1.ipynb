# %%
# %matplotlib notebook
# %pylab

# %% [markdown]
# #Hat function : Your results are right.  And no, you can’t really combine them - this is a piecewise defined function.   If you can plot it, that would be great.   Might take more than one where call.   The piece in $0 < x < \varepsilon/2$ can also be written $1-2(1-\eta)^2$.
# Heat kernel :  There are different ways to express the resulting function, but your answer should involve $\varepsilon$.    For this one, you don’t need to make the substitution $x = -\varepsilon/2 + \eta \varepsilon$, but can use the fact that
# \begin{equation}
# \lim_{x \to \infty} \mbox{erf}(x) = 1
# \end{equation}
# and
# \begin{equation}
# \lim_{x \to -\infty} \mbox{erf}(x) = -1
# \end{equation}
# Also, $\mbox{erf}(x) + \mbox{erfc}(x) = 1$ might be useful.  You can plot your solution to see that you have a formulation that works.  But as I said, there could be more than one formulation, depending on whether you use erf or erfc. (edited)

# %% [markdown]
# # return K

# %%
# Graphs for exercise 1

epsilon=0.01

# Set function
def Stepfunct(x):
    K = np.where(abs(x)<=(epsilon/2),(2/epsilon)*(1-(abs(2*(x))/epsilon)),0)
    return K

# Exact Solution
x=0.45
def Exact(x):
    return cos(x)
# print(Exact(x))

# approximation 𝐼(𝑥)
a=-1
b=1
# N=512
# Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
def f(phi):
    return Exact(phi)*Stepfunct(phi-x)

# Trapezoidale rule
def Trap(f,a,b,N):
    h=(b-a)/N
    T=0
    for i in range(N):
        T+=h/2*(f(phi[i]) + f(phi[i+1]))
    return T
Trap(f,-epsilon/2,epsilon/2,N)

# trapezoidal rule approximation
Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
phi=linspace(a,b,N+1)
for i in range(len(Nvec)):
#     x=linspace(-1,1,Nvec[i]+1)
    phi=linspace(a,b,Nvec[i]+1)
    Fx = Trap(f,-epsilon/2,epsilon/2,Nvec[i])
#     print(Fx)
    print("{:8d} {:24.16f} {:12.4e}".format(Nvec[i],Fx,abs(Fx-cos(0.45))))
# Out:
#       16       0.0000000000000000   9.0045e-01
#       32       0.0000000000000000   9.0045e-01
#       64       0.0000000000000000   9.0045e-01
#      128       0.0052680670345321   8.9518e-01
#      256       0.0030746956770502   8.9737e-01
#      512       0.0045062491321492   8.9594e-01
#     1024       0.0043968092859373   8.9605e-01

# %%
# N=512 a single value
# Graphs for exercise 1
epsilon=0.05
x=linspace(-1,1,1001)

# %%
def Stepfunct(x):
    K = np.where(abs(x)<=(epsilon/2),(2/epsilon)*(1-(abs(2*(x))/epsilon)),0)
    return K

# S=np.where(abs(x)<=(epsilon/2),(1/epsilon),0)
# K=Stepfunct(x)
# print(K)
# plt.plot(x,S, "b")

# %%
# Exact Solution
x_ext=0.45
def Exact(x):
    return cos(x)
print(Exact(x_ext))
# Out:
# 0.9004471023526769

# %%
a=-1
b=1
N=512
# Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
def f(phi,x):
    return Exact(phi)*Stepfunct(phi-x)

# %%
x=0.45
# x=linspace(-1,1,N+1)
phi=linspace(a,b,N+1)
XX=f(phi,x)
plt.plot(phi,XX)
# print(XX)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Trapezoidale rule
def Trap(f,a,b,N):
    h=(b-a)/N
    T=0
    for i in range(N):
        T+=h/2*(f(phi[i],x[i]) + f(phi[i+1],x[i+1]))
    return T
Trap(f,-epsilon/2,epsilon/2,512)
# Out:
# 1.6829398296438733

# %%
Nvec=np.array([16, 32, 64, 128, 256, 512, 1024])
phi=linspace(a,b,N+1)
for i in range(len(Nvec)):
#     x=linspace(-1,1,Nvec[i]+1)
    phi=linspace(a,b,Nvec[i]+1)
    Fx = Trap(f,-epsilon/2,epsilon/2,Nvec[i])
#     print(Fx)
    print("{:8d} {:24.16f} {:12.4e}".format(Nvec[i],Fx,abs(Fx-cos(0.45))))
# Out:
#       16       0.0337688941167587   8.6668e-01
#       32       0.0168844470583794   8.8356e-01
#       64       0.0084422235291897   8.9200e-01
#      128       0.0081391123122533   8.9231e-01
#      256       0.0092533909686645   8.9119e-01
#      512       0.0138673762797987   8.8658e-01
#     1024       1.6829414346229148   7.8249e-01

# %%
Fx = Trap(f,a,b,N)
# print(Fx)    
# print (N, "\t ", Fx, "\t",abs(Fx-cos(0.45)))

# COMMENT : Print out enough digits to see if your solution matches the one above
print("{:8d} {:24.16f} {:12.4e}".format(N,Fx[0],abs(Fx[0]-cos(0.45))))    

Fx_expected = 1.0556039797441716  # From table above
print("{:8d} {:24.16f} {:12.4e}".format(N,Fx_expected,abs(Fx_expected-cos(0.45))))
